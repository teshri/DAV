# %%
import pandas as pd
import numpy as np
filename='C:/Users/shadj/Desktop/Shad/DAV/Practicals/Book1.xlsx'
df1=pd.read_excel(filename)
df1
# Out:
#    Unnamed: 0     Name        TOJ  Duration
# 0           1      Ritu  10:05:00        50
# 1           2     Karan  10:15:00        40
# 2           3     Jatin  10:15:00        30
# 3           4     Rohit  10:25:00        30
# 4           5      Shad  10:30:00        50
# 5           6     Kunal  10:20:00        40
# 6           7  Kartikey  10:45:00        30
# 7           8       Ria  10:50:00        40
# 8           9     Aryan  10:55:00        40

# %%
df2=pd.read_excel(filename,sheet_name='Sheet2')
df2
# Out:
#    Unnamed: 0   Name        TOJ  Duration
# 0           1    Ritu  10:05:00        50
# 1           2   Nipun  10:15:00        40
# 2           3   Jatin  10:15:00        30
# 3           4  Gaurav  10:25:00        30
# 4           5    Shad  10:30:00        50
# 5           6   Kunal  10:20:00        40
# 6           7  Ritesh  10:45:00        30
# 7           8   Nakul  10:50:00        40
# 8           9  Vikram  10:55:00        40

# %% [markdown]
# a) Perform merging of the two dataframes to find the names of students who had attended the
# workshop on both days.

# %%
df3=pd.merge(df1,df2,on="Name")
df3
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 df3=pd.merge(df1,df2,on="Name")
#       2 df3
#
# File ~\Python\Python310\lib\site-packages\pandas\core\reshape\merge.py:110, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      93 @Substitution("\nleft : DataFrame or named Series")
#      94 @Appender(_merge_doc, indents=0)
#      95 def merge(
#    (...)
#     108     validate: str | None = None,
#     109 ) -> DataFrame:
# --> 110     op = _MergeOperation(
#     111         left,
#     112         right,
#     113         how=how,
#     114         on=on,
#     115         left_on=left_on,
#     116         right_on=right_on,
#     117         left_index=left_index,
#     118         right_index=right_index,
#     119         sort=sort,
# ...
