# %% [markdown]
# # #DAV Practical - 5
# Shad Jamil
# CSC/21/45

# %%
from ucimlrepo import fetch_ucirepo
import pandas as pd
import scipy
import seaborn as sns
import numpy as np
iris = fetch_ucirepo(id=53)
x=iris.data.features
x
# Out:
#      sepal length  sepal width  petal length  petal width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
x.plot.bar()
# Out:
# <AxesSubplot: >

# %%
sns.regplot(x="sepal width",y="petal width", data=x)
# Out:
# <AxesSubplot: xlabel='sepal width', ylabel='petal width'>

# %%
x["petal length"].plot.density()
# Out:
# <AxesSubplot: ylabel='Density'>

# %%
sns.pairplot(data=x,diag_kind='kde')
